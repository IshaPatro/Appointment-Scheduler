# %% [markdown]
# <a href="https://colab.research.google.com/github/IshaPatro/Appointment-Scheduler/blob/master/TimeSeriesBajajFinsrv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BAJAJFINSV stock

# %% [markdown]
# ###Imports

# %%
from google.colab import drive
import pandas as pd

# %% [markdown]
# ### Fetching the Dataset

# %%
drive.mount('/content/drive')
path = "/content/drive/MyDrive/Colab Notebooks/TimeSeries/BAJFINANCE.csv"
df = pd.read_csv(path)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          Date      Symbol Series  Prev Close   Open   High   Low   Last  \
# 0  2000-01-03  BAJAUTOFIN     EQ       46.95  49.45  50.75  46.5  50.75
# 1  2000-01-04  BAJAUTOFIN     EQ       50.75  53.20  53.20  47.9  48.00
# 2  2000-01-05  BAJAUTOFIN     EQ       48.10  46.55  47.40  44.6  44.60
# 3  2000-01-06  BAJAUTOFIN     EQ       44.60  43.50  46.00  42.1  46.00
# 4  2000-01-07  BAJAUTOFIN     EQ       45.25  48.00  48.00  42.0  42.90
#
#    Close   VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  50.75  50.05    7600  3.803800e+10     NaN                 NaN          NaN
# 1  48.10  48.56    5000  2.428000e+10     NaN                 NaN          NaN
# 2  44.60  45.47    3500  1.591450e+10     NaN                 NaN          NaN
# 3  45.25  44.43    6200  2.754750e+10     NaN                 NaN          NaN
# ...

# %%
df['VWAP'].plot()
# Out:
# <Axes: >
